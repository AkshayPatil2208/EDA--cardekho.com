# %% [markdown]
# # Exploratory Data Analysis
# # Data Mnupulation
# #31-03-2021

# %%
#Data Manupulation
import pandas as pd
import numpy as np

# %%
#Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Car details v3.csv')

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.head().T
# Out:
#                                     0                             1  \
# name           Maruti Swift Dzire VDI  Skoda Rapid 1.5 TDI Ambition
# year                             2014                          2014
# selling_price                  450000                        370000
# km_driven                      145500                        120000
# fuel                           Diesel                        Diesel
# seller_type                Individual                    Individual
# transmission                   Manual                        Manual
# owner                     First Owner                  Second Owner
# mileage                     23.4 kmpl                    21.14 kmpl
# engine                        1248 CC                       1498 CC
# max_power                      74 bhp                    103.52 bhp
# torque                 190Nm@ 2000rpm           250Nm@ 1500-2500rpm
# seats                               5                             5
#
#                                       2                          3  \
# name           Honda City 2017-2020 EXi  Hyundai i20 Sportz Diesel
# year                               2006                       2010
# selling_price                    158000                     225000
# km_driven                        140000                     127000
# fuel                             Petrol                     Diesel
# seller_type                  Individual                 Individual
# transmission                     Manual                     Manual
# owner                       Third Owner                First Owner
# mileage                       17.7 kmpl                  23.0 kmpl
# engine                          1497 CC                    1396 CC
# max_power                        78 bhp                     90 bhp
# torque            12.7@ 2,700(kgm@ rpm)   22.4 kgm at 1750-2750rpm
# seats                                 5                          5
#
#                                     4
# name           Maruti Swift VXI BSIII
# year                             2007
# selling_price                  130000
# km_driven                      120000
# fuel                           Petrol
# seller_type                Individual
# transmission                   Manual
# owner                     First Owner
# mileage                     16.1 kmpl
# engine                        1298 CC
# max_power                    88.2 bhp
# torque          11.5@ 4,500(kgm@ rpm)
# seats                               5

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
txt='My name is Akshay'
txt.split()
# Out:
# ['My', 'name', 'is', 'Akshay']

# %%
df_m=df['mileage'].str.split(expand=True)
df_m
# Out:
#           0     1
# 0      23.4  kmpl
# 1     21.14  kmpl
# 2      17.7  kmpl
# 3      23.0  kmpl
# 4      16.1  kmpl
# ...     ...   ...
# 8123   18.5  kmpl
# 8124   16.8  kmpl
# 8125   19.3  kmpl
# 8126  23.57  kmpl
# 8127  23.57  kmpl
#
# [8128 rows x 2 columns]

# %%
df['new_mileage']=df_m[0]
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats new_mileage
# 0            190Nm@ 2000rpm    5.0        23.4
# 1       250Nm@ 1500-2500rpm    5.0       21.14
# 2     12.7@ 2,700(kgm@ rpm)    5.0        17.7
# 3  22.4 kgm at 1750-2750rpm    5.0        23.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0        16.1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
#  13  new_mileage    7907 non-null   object
# dtypes: float64(1), int64(3), object(10)
# memory usage: 889.1+ KB

# %%
df['new_mileage']=df['new_mileage'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
#  13  new_mileage    7907 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 889.1+ KB

# %%
df_e=df['engine'].str.split(expand=True)
df_e
# Out:
#          0   1
# 0     1248  CC
# 1     1498  CC
# 2     1497  CC
# 3     1396  CC
# 4     1298  CC
# ...    ...  ..
# 8123  1197  CC
# 8124  1493  CC
# 8125  1248  CC
# 8126  1396  CC
# 8127  1396  CC
#
# [8128 rows x 2 columns]

# %%
df['new_engine']=df_e[0]
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  new_mileage new_engine
# 0            190Nm@ 2000rpm    5.0        23.40       1248
# 1       250Nm@ 1500-2500rpm    5.0        21.14       1498
# 2     12.7@ 2,700(kgm@ rpm)    5.0        17.70       1497
# 3  22.4 kgm at 1750-2750rpm    5.0        23.00       1396
# 4     11.5@ 4,500(kgm@ rpm)    5.0        16.10       1298

# %%
df['new_engine']=df['new_engine'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
#  13  new_mileage    7907 non-null   float64
#  14  new_engine     7907 non-null   float64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 952.6+ KB

# %%
df_p=df['max_power'].str.split(expand=True)
df_p
# Out:
#            0    1
# 0         74  bhp
# 1     103.52  bhp
# 2         78  bhp
# 3         90  bhp
# 4       88.2  bhp
# ...      ...  ...
# 8123   82.85  bhp
# 8124     110  bhp
# 8125    73.9  bhp
# 8126      70  bhp
# 8127      70  bhp
#
# [8128 rows x 2 columns]

# %%
df['new_max_power']=df_p[0]
df.head().T
# Out:
#                                     0                             1  \
# name           Maruti Swift Dzire VDI  Skoda Rapid 1.5 TDI Ambition
# year                             2014                          2014
# selling_price                  450000                        370000
# km_driven                      145500                        120000
# fuel                           Diesel                        Diesel
# seller_type                Individual                    Individual
# transmission                   Manual                        Manual
# owner                     First Owner                  Second Owner
# mileage                     23.4 kmpl                    21.14 kmpl
# engine                        1248 CC                       1498 CC
# max_power                      74 bhp                    103.52 bhp
# torque                 190Nm@ 2000rpm           250Nm@ 1500-2500rpm
# seats                               5                             5
# new_mileage                      23.4                         21.14
# new_engine                       1248                          1498
# new_max_power                      74                        103.52
#
#                                       2                          3  \
# name           Honda City 2017-2020 EXi  Hyundai i20 Sportz Diesel
# year                               2006                       2010
# selling_price                    158000                     225000
# km_driven                        140000                     127000
# fuel                             Petrol                     Diesel
# seller_type                  Individual                 Individual
# transmission                     Manual                     Manual
# owner                       Third Owner                First Owner
# mileage                       17.7 kmpl                  23.0 kmpl
# engine                          1497 CC                    1396 CC
# max_power                        78 bhp                     90 bhp
# torque            12.7@ 2,700(kgm@ rpm)   22.4 kgm at 1750-2750rpm
# seats                                 5                          5
# new_mileage                        17.7                         23
# new_engine                         1497                       1396
# new_max_power                        78                         90
#
#                                     4
# name           Maruti Swift VXI BSIII
# year                             2007
# selling_price                  130000
# km_driven                      120000
# fuel                           Petrol
# seller_type                Individual
# transmission                   Manual
# owner                     First Owner
# mileage                     16.1 kmpl
# engine                        1298 CC
# max_power                    88.2 bhp
# torque          11.5@ 4,500(kgm@ rpm)
# seats                               5
# new_mileage                      16.1
# new_engine                       1298
# new_max_power                    88.2

# %%
df['new_max_power']=df['new_max_power'].astype(float)
df.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-f32e351c75c8> in <module>
# ----> 1 df['new_max_power']=df['new_max_power'].astype(float)
#       2 df.info()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     593             vals1d = values.ravel()
#     594             try:
# --> 595                 values = astype_nansafe(vals1d, dtype, copy=True)
#     596             except (ValueError, TypeError):
#     597                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     993     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     994         # Explicit copy, or required since NumPy can't view from / to object.
# --> 995         return arr.astype(dtype, copy=True)
#     996
#     997     return arr.view(dtype)
#
# ValueError: could not convert string to float: 'bhp'

# %%
df[df['name']=='Maruti Omni CNG']
# Out:
#                  name  year  selling_price  km_driven fuel seller_type  \
# 4933  Maruti Omni CNG  2000          80000     100000  CNG  Individual
#
#      transmission         owner     mileage  engine max_power torque  seats  \
# 4933       Manual  Second Owner  10.9 km/kg  796 CC       bhp    NaN    8.0
#
#       new_mileage  new_engine new_max_power
# 4933         10.9       796.0           bhp

# %%
df[(df['new_engine']>=796) & (df['fuel']=='CNG')]
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats  new_mileage  new_engine  \
# 0         74 bhp             190Nm@ 2000rpm    5.0        23.40      1248.0
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0        21.14      1498.0
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0        17.70      1497.0
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0        23.00      1396.0
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0        16.10      1298.0
# ...          ...                        ...    ...          ...         ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0        18.50      1197.0
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0        16.80      1493.0
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0        19.30      1248.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0        23.57      1396.0
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0        23.57      1396.0
#
#      new_max_power
# 0               74
# 1           103.52
# 2               78
# 3               90
# 4             88.2
# ...            ...
# 8123         82.85
# 8124           110
# 8125          73.9
# 8126            70
# 8127            70
#
# [8128 rows x 16 columns]

# %%
df=df.replace({'new_max_power':{"bhp":40.3}})
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats  new_mileage  new_engine  \
# 0         74 bhp             190Nm@ 2000rpm    5.0        23.40      1248.0
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0        21.14      1498.0
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0        17.70      1497.0
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0        23.00      1396.0
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0        16.10      1298.0
# ...          ...                        ...    ...          ...         ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0        18.50      1197.0
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0        16.80      1493.0
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0        19.30      1248.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0        23.57      1396.0
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0        23.57      1396.0
#
#      new_max_power
# 0               74
# 1           103.52
# 2               78
# 3               90
# 4             88.2
# ...            ...
# 8123         82.85
# 8124           110
# 8125          73.9
# 8126            70
# 8127            70
#
# [8128 rows x 16 columns]

# %%
df[df['new_max_power'].str.contains("bhp")==True]
# Out:
# Empty DataFrame
# Columns: [name, year, selling_price, km_driven, fuel, seller_type, transmission, owner, mileage, engine, max_power, torque, seats, new_mileage, new_engine, new_max_power]
# Index: []

# %%
df[(df['new_engine']>=796) & (df['new_engine']<800)]
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats  new_mileage  new_engine  \
# 0         74 bhp             190Nm@ 2000rpm    5.0        23.40      1248.0
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0        21.14      1498.0
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0        17.70      1497.0
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0        23.00      1396.0
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0        16.10      1298.0
# ...          ...                        ...    ...          ...         ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0        18.50      1197.0
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0        16.80      1493.0
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0        19.30      1248.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0        23.57      1396.0
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0        23.57      1396.0
#
#      new_max_power
# 0               74
# 1           103.52
# 2               78
# 3               90
# 4             88.2
# ...            ...
# 8123         82.85
# 8124           110
# 8125          73.9
# 8126            70
# 8127            70
#
# [8128 rows x 16 columns]

# %%
df[df['new_engine']==796]
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 7               Maruti 800 DX BSII  2001          45000       5000  Petrol
# 18                  Maruti Alto LX  2002         150000      80000  Petrol
# 26             Maruti Alto 800 LXI  2017         275000      28000  Petrol
# 29     Maruti Omni E MPI STD BS IV  2018         254999      25000  Petrol
# 32       Maruti Omni 8 Seater BSIV  2012         150000      35000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8028           Maruti Alto 800 VXI  2016         320000      46737  Petrol
# 8035  Maruti Alto 800 LXI Optional  2018         310000      20000  Petrol
# 8044         Maruti Alto LXi BSIII  2006         120000      70000  Petrol
# 8114               Maruti Alto LXi  2011         200000      73000  Petrol
# 8115                 Maruti 800 AC  1997          40000     120000  Petrol
#
#      seller_type transmission         owner     mileage  engine max_power  \
# 7     Individual       Manual  Second Owner   16.1 kmpl  796 CC    37 bhp
# 18    Individual       Manual  Second Owner   19.7 kmpl  796 CC  46.3 bhp
# 26    Individual       Manual   First Owner   24.7 kmpl  796 CC  47.3 bhp
# 29    Individual       Manual   First Owner   16.8 kmpl  796 CC  34.2 bhp
# 32    Individual       Manual  Second Owner   14.0 kmpl  796 CC    35 bhp
# ...          ...          ...           ...         ...     ...       ...
# 8028  Individual       Manual   First Owner  22.74 kmpl  796 CC  47.3 bhp
# 8035  Individual       Manual   First Owner   24.7 kmpl  796 CC  47.3 bhp
# 8044  Individual       Manual   Third Owner   19.7 kmpl  796 CC  46.3 bhp
# 8114  Individual       Manual   First Owner   19.7 kmpl  796 CC  46.3 bhp
# 8115  Individual       Manual   First Owner   16.1 kmpl  796 CC    37 bhp
#
#                torque  seats  new_mileage  new_engine new_max_power
# 7       59Nm@ 2500rpm    4.0        16.10       796.0            37
# 18      62Nm@ 3000rpm    5.0        19.70       796.0          46.3
# 26      69Nm@ 3500rpm    5.0        24.70       796.0          47.3
# 29      59Nm@ 2500rpm    8.0        16.80       796.0          34.2
# 32    6.1kgm@ 3000rpm    5.0        14.00       796.0            35
# ...               ...    ...          ...         ...           ...
# 8028    69Nm@ 3500rpm    5.0        22.74       796.0          47.3
# 8035    69Nm@ 3500rpm    5.0        24.70       796.0          47.3
# 8044    62Nm@ 3000rpm    5.0        19.70       796.0          46.3
# 8114    62Nm@ 3000rpm    5.0        19.70       796.0          46.3
# 8115    59Nm@ 2500rpm    4.0        16.10       796.0            37
#
# [444 rows x 16 columns]

# %%
df['new_max_power']=df['new_max_power'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
#  13  new_mileage    7907 non-null   float64
#  14  new_engine     7907 non-null   float64
#  15  new_max_power  7913 non-null   float64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 1016.1+ KB

# %%
df=df.drop(['mileage','engine','max_power'],axis=1)

# %%
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner  \
# 0     Individual       Manual           First Owner
# 1     Individual       Manual          Second Owner
# 2     Individual       Manual           Third Owner
# 3     Individual       Manual           First Owner
# 4     Individual       Manual           First Owner
# ...          ...          ...                   ...
# 8123  Individual       Manual           First Owner
# 8124  Individual       Manual  Fourth & Above Owner
# 8125  Individual       Manual           First Owner
# 8126  Individual       Manual           First Owner
# 8127  Individual       Manual           First Owner
#
#                          torque  seats  new_mileage  new_engine  new_max_power
# 0                190Nm@ 2000rpm    5.0        23.40      1248.0          74.00
# 1           250Nm@ 1500-2500rpm    5.0        21.14      1498.0         103.52
# 2         12.7@ 2,700(kgm@ rpm)    5.0        17.70      1497.0          78.00
# 3      22.4 kgm at 1750-2750rpm    5.0        23.00      1396.0          90.00
# 4         11.5@ 4,500(kgm@ rpm)    5.0        16.10      1298.0          88.20
# ...                         ...    ...          ...         ...            ...
# 8123           113.7Nm@ 4000rpm    5.0        18.50      1197.0          82.85
# 8124  24@ 1,900-2,750(kgm@ rpm)    5.0        16.80      1493.0         110.00
# 8125             190Nm@ 2000rpm    5.0        19.30      1248.0          73.90
# 8126        140Nm@ 1800-3000rpm    5.0        23.57      1396.0          70.00
# 8127        140Nm@ 1800-3000rpm    5.0        23.57      1396.0          70.00
#
# [8128 rows x 13 columns]

# %%
df[df.duplicated()]
# Out:
#                                           name  year  selling_price  \
# 291                   Hyundai Grand i10 Sportz  2017         450000
# 296                           Maruti Swift VXI  2012         330000
# 370   Jaguar XE 2016-2019 2.0L Diesel Prestige  2017        2625000
# 371                              Lexus ES 300h  2019        5150000
# 372             Jaguar XF 2.0 Diesel Portfolio  2017        3200000
# ...                                        ...   ...            ...
# 7987             Renault Captur 1.5 Diesel RXT  2018        1265000
# 7988                  Maruti Ciaz Alpha Diesel  2019        1025000
# 8117                    Maruti Swift Dzire VDI  2015         625000
# 8126                           Tata Indigo CR4  2013         290000
# 8127                           Tata Indigo CR4  2013         290000
#
#       km_driven    fuel seller_type transmission         owner  \
# 291       35000  Petrol  Individual       Manual   First Owner
# 296       50000  Petrol  Individual       Manual  Second Owner
# 370        9000  Diesel      Dealer    Automatic   First Owner
# 371       20000  Petrol      Dealer    Automatic   First Owner
# 372       45000  Diesel      Dealer    Automatic   First Owner
# ...         ...     ...         ...          ...           ...
# 7987      12000  Diesel  Individual       Manual   First Owner
# 7988      32000  Diesel  Individual       Manual   First Owner
# 8117      50000  Diesel  Individual       Manual   First Owner
# 8126      25000  Diesel  Individual       Manual   First Owner
# 8127      25000  Diesel  Individual       Manual   First Owner
#
#                    torque  seats  new_mileage  new_engine  new_max_power
# 291        114Nm@ 4000rpm    5.0        18.90      1197.0          82.00
# 296        114Nm@ 4000rpm    5.0        18.60      1197.0          85.80
# 370   430Nm@ 1750-2500rpm    5.0        13.60      1999.0         177.00
# 371   202Nm@ 3600-5200rpm    5.0        22.37      2487.0         214.56
# 372   430Nm@ 1750-2500rpm    5.0        19.33      1999.0         177.00
# ...                   ...    ...          ...         ...            ...
# 7987       240Nm@ 1750rpm    5.0        20.37      1461.0         108.45
# 7988       200Nm@ 1750rpm    5.0        28.09      1248.0          88.50
# 8117       190Nm@ 2000rpm    5.0        26.59      1248.0          74.00
# 8126  140Nm@ 1800-3000rpm    5.0        23.57      1396.0          70.00
# 8127  140Nm@ 1800-3000rpm    5.0        23.57      1396.0          70.00
#
# [1202 rows x 13 columns]

# %%
len(df[df.duplicated()])
# Out:
# 1202

# %%
#Dropping the duplicate Rows
df=df.drop_duplicates(keep='first')

# %%
df.describe()
# Out:
#               year  selling_price     km_driven        seats  new_mileage  \
# count  6926.000000   6.926000e+03  6.926000e+03  6718.000000   6718.00000
# mean   2013.420300   5.172707e+05  7.399568e+04     5.434653     19.46531
# std       4.078286   5.197670e+05  5.835810e+04     0.984230      4.04915
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000      0.00000
# 25%    2011.000000   2.500000e+05  4.000000e+04     5.000000     16.80000
# 50%    2014.000000   4.000000e+05  7.000000e+04     5.000000     19.44000
# 75%    2017.000000   6.335000e+05  1.000000e+05     5.000000     22.50000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000     42.00000
#
#         new_engine  new_max_power
# count  6718.000000    6721.000000
# mean   1430.891337      87.719862
# std     493.493277      31.774522
# min     624.000000       0.000000
# 25%    1197.000000      67.100000
# 50%    1248.000000      81.830000
# 75%    1498.000000     100.000000
# max    3604.000000     400.000000

# %%
df.replace(
{
    'new_mileage':{0:df['new_mileage'].mean()},
    'new_max_power':{0:df['new_max_power'].mean()}
},
    inplace=True
)
# Out:
# C:\Users\Akshay.LAPTOP-28VV15LR\anaconda3\lib\site-packages\pandas\core\indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
df.isnull()
# Out:
#        name   year  selling_price  km_driven   fuel  seller_type  \
# 0     False  False          False      False  False        False
# 1     False  False          False      False  False        False
# 2     False  False          False      False  False        False
# 3     False  False          False      False  False        False
# 4     False  False          False      False  False        False
# ...     ...    ...            ...        ...    ...          ...
# 8121  False  False          False      False  False        False
# 8122  False  False          False      False  False        False
# 8123  False  False          False      False  False        False
# 8124  False  False          False      False  False        False
# 8125  False  False          False      False  False        False
#
#       transmission  owner  torque  seats  new_mileage  new_engine  \
# 0            False  False   False  False        False       False
# 1            False  False   False  False        False       False
# 2            False  False   False  False        False       False
# 3            False  False   False  False        False       False
# 4            False  False   False  False        False       False
# ...            ...    ...     ...    ...          ...         ...
# 8121         False  False   False  False        False       False
# 8122         False  False   False  False        False       False
# 8123         False  False   False  False        False       False
# 8124         False  False   False  False        False       False
# 8125         False  False   False  False        False       False
#
#       new_max_power
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 8121          False
# 8122          False
# 8123          False
# 8124          False
# 8125          False
#
# [6926 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# torque           209
# seats            208
# new_mileage      208
# new_engine       208
# new_max_power    205
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# name             0.000000
# year             0.000000
# selling_price    0.000000
# km_driven        0.000000
# fuel             0.000000
# seller_type      0.000000
# transmission     0.000000
# owner            0.000000
# torque           3.017615
# seats            3.003176
# new_mileage      3.003176
# new_engine       3.003176
# new_max_power    2.959861
# dtype: float64

# %%
df['new_mileage'].mean()
# Out:
# 19.508771902982932

# %%
df['new_max_power'].mean()
# Out:
# 87.75901719790329

# %%
df['seats'].mean()
# Out:
# 5.4346531705864844

# %%
df['new_engine'].fillna(df['new_engine'].mean(),inplace=True)
df['new_mileage'].fillna(df['new_mileage'].mean(),inplace=True)
df['new_max_power'].fillna(df['new_max_power'].mean(),inplace=True)
df['seats'].fillna(5,inplace=True)
# Out:
# C:\Users\Akshay.LAPTOP-28VV15LR\anaconda3\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df.isnull().mean()*100
# Out:
# name             0.000000
# year             0.000000
# selling_price    0.000000
# km_driven        0.000000
# fuel             0.000000
# seller_type      0.000000
# transmission     0.000000
# owner            0.000000
# torque           3.017615
# seats            0.000000
# new_mileage      0.000000
# new_engine       0.000000
# new_max_power    0.000000
# dtype: float64

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner                    torque  seats  \
# 0  Individual       Manual   First Owner            190Nm@ 2000rpm    5.0
# 1  Individual       Manual  Second Owner       250Nm@ 1500-2500rpm    5.0
# 2  Individual       Manual   Third Owner     12.7@ 2,700(kgm@ rpm)    5.0
# 3  Individual       Manual   First Owner  22.4 kgm at 1750-2750rpm    5.0
# 4  Individual       Manual   First Owner     11.5@ 4,500(kgm@ rpm)    5.0
#
#    new_mileage  new_engine  new_max_power
# 0        23.40      1248.0          74.00
# 1        21.14      1498.0         103.52
# 2        17.70      1497.0          78.00
# 3        23.00      1396.0          90.00
# 4        16.10      1298.0          88.20

# %%
df=df.drop(['torque'],axis=1)

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  seats  new_mileage  new_engine  \
# 0  Individual       Manual   First Owner    5.0        23.40      1248.0
# 1  Individual       Manual  Second Owner    5.0        21.14      1498.0
# 2  Individual       Manual   Third Owner    5.0        17.70      1497.0
# 3  Individual       Manual   First Owner    5.0        23.00      1396.0
# 4  Individual       Manual   First Owner    5.0        16.10      1298.0
#
#    new_max_power
# 0          74.00
# 1         103.52
# 2          78.00
# 3          90.00
# 4          88.20

# %%
import datetime
now=datetime.datetime.now()
now.year
# Out:
# 2021

# %%
now
# Out:
# datetime.datetime(2021, 4, 3, 19, 59, 35, 571978)

# %%
df['car_age']=now.year-df['year']
df.head().T
# Out:
#                                     0                             1  \
# name           Maruti Swift Dzire VDI  Skoda Rapid 1.5 TDI Ambition
# year                             2014                          2014
# selling_price                  450000                        370000
# km_driven                      145500                        120000
# fuel                           Diesel                        Diesel
# seller_type                Individual                    Individual
# transmission                   Manual                        Manual
# owner                     First Owner                  Second Owner
# seats                               5                             5
# new_mileage                      23.4                         21.14
# new_engine                       1248                          1498
# new_max_power                      74                        103.52
# car_age                             7                             7
#
#                                       2                          3  \
# name           Honda City 2017-2020 EXi  Hyundai i20 Sportz Diesel
# year                               2006                       2010
# selling_price                    158000                     225000
# km_driven                        140000                     127000
# fuel                             Petrol                     Diesel
# seller_type                  Individual                 Individual
# transmission                     Manual                     Manual
# owner                       Third Owner                First Owner
# seats                                 5                          5
# new_mileage                        17.7                         23
# new_engine                         1497                       1396
# new_max_power                        78                         90
# car_age                              15                         11
#
#                                     4
# name           Maruti Swift VXI BSIII
# year                             2007
# selling_price                  130000
# km_driven                      120000
# fuel                           Petrol
# seller_type                Individual
# transmission                   Manual
# owner                     First Owner
# seats                               5
# new_mileage                      16.1
# new_engine                       1298
# new_max_power                    88.2
# car_age                            14

# %% [markdown]
# df.drop('year',axis=1,inplace=True)
# df.columns

# %% [markdown]
# # Univarite Analysis

# %%
#1-4-2021

# %%
#Univarite Analysis 
#countplot-caterorical data,
#Histogram-numerical data(skewness,data transform)

# %%
#1.cleaned data
#2.null values/ 0 values
#3.removed duplication
#4.removed outliers

# %%
#5.univariate analysis
#--category-countplot-- clubbed minority values into one catogery
#--numerical-histogram-based on shape of histogram--apply data transformation eg log,sqrt

# %%
#6.bivarite analysis
#--cat--boxplot
#Num--Co-relation--delete which have very low co relation with dependent variable
               #--delete one high corelated variables to avoid multi-coliniarity or usual reguralization based model

# %%
#7.encoding techniques for converting categorical data--> numeric data

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner  seats  \
# 0     Diesel  Individual       Manual           First Owner    5.0
# 1     Diesel  Individual       Manual          Second Owner    5.0
# 2     Petrol  Individual       Manual           Third Owner    5.0
# 3     Diesel  Individual       Manual           First Owner    5.0
# 4     Petrol  Individual       Manual           First Owner    5.0
# ...      ...         ...          ...                   ...    ...
# 8121  Petrol  Individual       Manual          Second Owner    5.0
# 8122  Diesel  Individual       Manual          Second Owner    5.0
# 8123  Petrol  Individual       Manual           First Owner    5.0
# 8124  Diesel  Individual       Manual  Fourth & Above Owner    5.0
# 8125  Diesel  Individual       Manual           First Owner    5.0
#
#       new_mileage  new_engine  new_max_power  car_age
# 0           23.40      1248.0          74.00        7
# 1           21.14      1498.0         103.52        7
# 2           17.70      1497.0          78.00       15
# 3           23.00      1396.0          90.00       11
# 4           16.10      1298.0          88.20       14
# ...           ...         ...            ...      ...
# 8121        18.90       998.0          67.10        8
# 8122        22.54      1396.0          88.73        7
# 8123        18.50      1197.0          82.85        8
# 8124        16.80      1493.0         110.00       14
# 8125        19.30      1248.0          73.90       12
#
# [6926 rows x 13 columns]

# %%
sns.countplot(x=df['fuel'])
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='count'>

# %%
df['fuel'].value_counts()
# Out:
# Diesel    3755
# Petrol    3077
# CNG         56
# LPG         38
# Name: fuel, dtype: int64

# %%
sns.countplot(x=df['seller_type'])
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='count'>

# %%
sns.countplot(x=df['transmission'])
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='count'>

# %%
sns.countplot(x=df['owner'])
# Out:
# <AxesSubplot:xlabel='owner', ylabel='count'>

# %%
sns.distplot(x=df['new_engine'])
# Out:
# C:\Users\Akshay.LAPTOP-28VV15LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(df['car_age'],bins=10,hist_kws=dict(edgecolor='black',linewidth=2))
# Out:
# C:\Users\Akshay.LAPTOP-28VV15LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='car_age', ylabel='Density'>

# %%
sns.distplot(df['new_max_power'])
# Out:
# C:\Users\Akshay.LAPTOP-28VV15LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='new_max_power', ylabel='Density'>

# %%
sns.distplot(df['new_mileage'])
# Out:
# C:\Users\Akshay.LAPTOP-28VV15LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='new_mileage', ylabel='Density'>

# %%
sns.distplot(df['selling_price'])
# Out:
# C:\Users\Akshay.LAPTOP-28VV15LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='selling_price', ylabel='Density'>

# %%
sns.distplot(df['km_driven'])
# Out:
# C:\Users\Akshay.LAPTOP-28VV15LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='km_driven', ylabel='Density'>

# %% [markdown]
# # Bivarite Analysis

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner  seats  \
# 0     Diesel  Individual       Manual           First Owner    5.0
# 1     Diesel  Individual       Manual          Second Owner    5.0
# 2     Petrol  Individual       Manual           Third Owner    5.0
# 3     Diesel  Individual       Manual           First Owner    5.0
# 4     Petrol  Individual       Manual           First Owner    5.0
# ...      ...         ...          ...                   ...    ...
# 8121  Petrol  Individual       Manual          Second Owner    5.0
# 8122  Diesel  Individual       Manual          Second Owner    5.0
# 8123  Petrol  Individual       Manual           First Owner    5.0
# 8124  Diesel  Individual       Manual  Fourth & Above Owner    5.0
# 8125  Diesel  Individual       Manual           First Owner    5.0
#
#       new_mileage  new_engine  new_max_power  car_age
# 0           23.40      1248.0          74.00        7
# 1           21.14      1498.0         103.52        7
# 2           17.70      1497.0          78.00       15
# 3           23.00      1396.0          90.00       11
# 4           16.10      1298.0          88.20       14
# ...           ...         ...            ...      ...
# 8121        18.90       998.0          67.10        8
# 8122        22.54      1396.0          88.73        7
# 8123        18.50      1197.0          82.85        8
# 8124        16.80      1493.0         110.00       14
# 8125        19.30      1248.0          73.90       12
#
# [6926 rows x 13 columns]

# %%
#Bivarite Analysis with numeric values

# %%
cormat=df.corr()

# %%
#co-relation matrix
cormat
# Out:
#                    year  selling_price  km_driven     seats  new_mileage  \
# year           1.000000       0.433076  -0.377003  0.042275     0.351490
# selling_price  0.433076       1.000000  -0.165620  0.163942    -0.106982
# km_driven     -0.377003      -0.165620   1.000000  0.200999    -0.202287
# seats          0.042275       0.163942   0.200999  1.000000    -0.479937
# new_mileage    0.351490      -0.106982  -0.202287 -0.479937     1.000000
# new_engine    -0.017967       0.439321   0.250966  0.655879    -0.591270
# new_max_power  0.151181       0.686833   0.041271  0.257520    -0.388043
# car_age       -1.000000      -0.433076   0.377003 -0.042275    -0.351490
#
#                new_engine  new_max_power   car_age
# year            -0.017967       0.151181 -1.000000
# selling_price    0.439321       0.686833 -0.433076
# km_driven        0.250966       0.041271  0.377003
# seats            0.655879       0.257520 -0.042275
# new_mileage     -0.591270      -0.388043 -0.351490
# new_engine       1.000000       0.683594  0.017967
# new_max_power    0.683594       1.000000 -0.151181
# car_age          0.017967      -0.151181  1.000000

# %%
sns.heatmap(cormat,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=df['fuel'],y=df['selling_price'])
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='selling_price'>

# %%
sns.boxplot(x=df['transmission'],y=df['selling_price'])
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='selling_price'>

# %%
sns.boxplot(x=df['owner'],y=df['selling_price'])
# Out:
# <AxesSubplot:xlabel='owner', ylabel='selling_price'>

# %%
#investigation reason behind high car price for test drive cars
df[df['owner']=='First Owner']['selling_price']
# Out:
# 0       450000
# 3       225000
# 4       130000
# 5       440000
# 6        96000
#          ...
# 8118    380000
# 8119    360000
# 8120    120000
# 8123    320000
# 8125    382000
# Name: selling_price, Length: 4242, dtype: int64

# %%
#taking mean of selling price first owner car
df[df['owner']=='First Owner']['selling_price'].mean()
# Out:
# 615404.3995756719

# %%
df[df['owner']=='Second Owner']['selling_price'].mean()
# Out:
# 385697.1909827761

# %%
df[df['owner']=='Third Owner']['selling_price'].mean()
# Out:
# 281250.9496268657

# %%
df[df['owner']=='Fourth & Above Owner']['selling_price'].mean()
# Out:
# 224470.36686390534

# %%
df[df['owner']=='Test Drive Car']['selling_price'].mean()
# Out:
# 4403800.0

# %%
df.owner.value_counts()
# Out:
# First Owner             4242
# Second Owner            1974
# Third Owner              536
# Fourth & Above Owner     169
# Test Drive Car             5
# Name: owner, dtype: int64

# %%
df[df['owner']=='Test Drive Car']
# Out:
#                                         name  year  selling_price  km_driven  \
# 4383  Volkswagen Vento 1.5 TDI Highline BSIV  2019        1350000       5400
# 4950                  Audi A6 35 TFSI Matrix  2019        6223000       7800
# 4951                  Audi A6 35 TFSI Matrix  2019        5923000      11500
# 4952                  Audi A6 35 TFSI Matrix  2019        6523000      23600
# 6220                          Honda Civic ZX  2019        2000000      24857
#
#         fuel seller_type transmission           owner  seats  new_mileage  \
# 4383  Diesel      Dealer       Manual  Test Drive Car    5.0        22.27
# 4950  Petrol      Dealer    Automatic  Test Drive Car    5.0        15.26
# 4951  Petrol      Dealer    Automatic  Test Drive Car    5.0        15.26
# 4952  Petrol      Dealer    Automatic  Test Drive Car    5.0        15.26
# 6220  Petrol      Dealer    Automatic  Test Drive Car    5.0        16.50
#
#       new_engine  new_max_power  car_age
# 4383      1498.0         108.60        2
# 4950      1798.0         187.74        2
# 4951      1798.0         187.74        2
# 4952      1798.0         187.74        2
# 6220      1799.0         139.46        2

# %%
sns.distplot(df['selling_price'])
# Out:
# C:\Users\Akshay.LAPTOP-28VV15LR\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='selling_price', ylabel='Density'>

# %%
sns.boxplot(df['selling_price'])
# Out:
# C:\Users\Akshay.LAPTOP-28VV15LR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='selling_price'>

# %%
from scipy import stats
Q1=df['selling_price'].quantile(0.25)
Q1
# Out:
# 250000.0

# %%
Q3=df['selling_price'].quantile(0.75)
Q3
# Out:
# 633500.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 383500.0

# %%
from scipy import stats
IQR=stats.iqr(df['selling_price'])
IQR
# Out:
# 383500.0

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3-1.5*IQR
lower_limit,upper_limit
# Out:
# (-325250.0, 58250.0)

# %%
df_outliers=df[(df['selling_price']<lower_limit)|(df['selling_price']>upper_limit)]

# %%
df_outliers.shape
# Out:
# (6832, 13)

# %%
index=df[(df['selling_price']<lower_limit)|(df['selling_price']>upper_limit)].index
index
# Out:
# Int64Index([   0,    1,    2,    3,    4,    5,    6,    8,    9,   10,
#             ...
#             8114, 8116, 8118, 8119, 8120, 8121, 8122, 8123, 8124, 8125],
#            dtype='int64', length=6832)

# %%
df.drop(index, inplace=True)

# %%
sns.boxplot(x=df['fuel'],y=df['selling_price'])
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='selling_price'>

# %%
df.head()
# Out:
#                            name  selling_price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI         450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition         370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi         158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel         225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII         130000     120000  Petrol  Individual
#
#   transmission         owner  seats  new_mileage  new_engine  new_max_power  \
# 0       Manual   First Owner    5.0        23.40      1248.0          74.00
# 1       Manual  Second Owner    5.0        21.14      1498.0         103.52
# 2       Manual   Third Owner    5.0        17.70      1497.0          78.00
# 3       Manual   First Owner    5.0        23.00      1396.0          90.00
# 4       Manual   First Owner    5.0        16.10      1298.0          88.20
#
#    car_age
# 0        7
# 1        7
# 2       15
# 3       11
# 4       14

# %%
#encoding of categorical features--one hot encoding
pd.get_dummies(df['fuel'],drop_first=True)
# Out:
#       LPG  Petrol
# 7       0       1
# 78      0       0
# 177     0       1
# 206     0       1
# 709     0       1
# ...   ...     ...
# 7935    0       1
# 7958    0       1
# 8025    0       1
# 8089    0       1
# 8115    0       1
#
# [94 rows x 2 columns]

# %%
df.owner.value_counts()
# Out:
# Second Owner            36
# First Owner             25
# Third Owner             23
# Fourth & Above Owner    10
# Name: owner, dtype: int64

# %%
df.owner.replace(['First Owner','Second Owner','Third Owner','Fourth & Above Owner'],[4,3,2,1],inplace=True)

# %%
df.owner.value_counts()
# Out:
# 4    61
# 3    23
# 1    10
# Name: owner, dtype: int64

# %%
#Steps by step explanation
#1.cleaned data
#2.null values/ 0 values
#3.removed duplication
#4.removed outliers

# %%
#5.univariate analysis
#--category-countplot-- clubbed minority values into one catogery
#--numerical-histogram-based on shape of histogram--apply data transformation eg log,sqrt

# %%
#6.bivarite analysis
#--cat--boxplot
#num--corelation--delete which have very low co relation with dependent variable
               #--delete one high corelated variables to avoid multi-coliniarity or usual reguralization based model

# %%
#7.encoding techniques for converting categorical data--> numeric data
